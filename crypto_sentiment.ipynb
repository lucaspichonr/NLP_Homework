# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newsapi import NewsApiClient
from pathlib import Path
from dotenv import load_dotenv
load_dotenv()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
# Read your api key environment variable
# YOUR CODE HERE!
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
# YOUR CODE HERE!
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
btc_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Show sample article
btc_headlines["articles"][0]
# Out:
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Khari Johnson',
#  'title': 'Why Not Use Self-Driving Cars as Supercomputers?',
#  'description': 'Autonomous vehicles use the equivalent of 200 laptops to get around. Some want to tap that computing power to decode viruses or mine bitcoin.',
#  'url': 'https://www.wired.com/story/use-self-driving-cars-supercomputers/',
#  'urlToImage': 'https://media.wired.com/photos/60f081b4c147fe7a1a367362/191:100/w_1280,c_limit/Business-Autonomous-Vehicles-Supercomputers-1201885684.jpg',
#  'publishedAt': '2021-07-19T11:00:00Z',
#  'content': 'Like Dogecoin devotees, the mayor of Reno, and the leaders of El Salvador, Aldo Baoicchi is convinced cryptocurrency is the future. The CEO and founder of Canadian scooter maker Daymak believes this … [+4116 chars]'}

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
eth_headlines = newsapi.get_everything(
    q="ethereum",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# Show sample article
eth_headlines["articles"][0]
# Out:
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#  'author': 'Connie Loizos',
#  'title': 'Crypto investors like Terraform Labs so much, they’re committing $150 million to its ‘ecosystem’',
#  'description': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote about in May. Often, these technologies are seen as so prom…',
#  'url': 'http://techcrunch.com/2021/07/16/crypto-investors-like-terraform-labs-so-much-theyre-committing-150-million-to-its-ecosystem/',
#  'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1174590894.jpg?w=667',
#  'publishedAt': '2021-07-16T16:00:55Z',
#  'content': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote… [+2563 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
btc_sentiments = []

for article in btc_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-07-19  Like Dogecoin devotees, the mayor of Reno, and...    0.6908
# 1  2021-07-05  Filed under:\r\nThe supply chain attack has re...   -0.5719
# 2  2021-07-05  image copyrightGetty Images\r\nThe gang behind...   -0.6124
# 3  2021-07-23  To get a roundup of TechCrunchs biggest and mo...    0.6240
# 4  2021-07-14  While retail investors grew more comfortable b...    0.7264
#
#    positive  negative  neutral
# 0     0.178     0.000    0.822
# 1     0.111     0.184    0.705
# 2     0.000     0.143    0.857
# 3     0.127     0.000    0.873
# 4     0.164     0.000    0.836

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
eth_sentiments = []

for article in eth_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-07-16  There are many blockchain platforms competing ...    0.3612
# 1  2021-07-14  While retail investors grew more comfortable b...    0.7264
# 2  2021-07-02  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...    0.3612
# 3  2021-07-17  "Anthony Di Iorio, a co-founder of the Ethereu...    0.6369
# 4  2021-07-05  Ether holders have "staked" more than $13 bill...    0.7717
#
#    positive  negative  neutral
# 0     0.075     0.000    0.925
# 1     0.164     0.000    0.836
# 2     0.110     0.041    0.849
# 3     0.157     0.000    0.843
# 4     0.194     0.000    0.806

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
btc_df.describe()
# Out:
#          compound    positive    negative    neutral
# count  100.000000  100.000000  100.000000  100.00000
# mean     0.046143    0.045570    0.034170    0.92025
# std      0.374973    0.060143    0.059515    0.08208
# min     -0.827100    0.000000    0.000000    0.65300
# 25%     -0.051600    0.000000    0.000000    0.86775
# 50%      0.000000    0.000000    0.000000    0.92650
# 75%      0.301550    0.080250    0.067250    1.00000
# max      0.865800    0.276000    0.287000    1.00000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
eth_df.describe()
# Out:
#          compound    positive   negative     neutral
# count  100.000000  100.000000  100.00000  100.000000
# mean     0.152496    0.054010    0.02183    0.924170
# std      0.340071    0.059799    0.04313    0.070174
# min     -0.812600    0.000000    0.00000    0.714000
# 25%      0.000000    0.000000    0.00000    0.864250
# 50%      0.000000    0.042000    0.00000    0.927000
# 75%      0.461050    0.094750    0.04125    1.000000
# max      0.771700    0.194000    0.24900    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import reuters
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import nltk
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()
# Create a list of stopwords
# YOUR CODE HERE!
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('reuters')
nltk.download('stopwords')
nltk.download('punkt')
# Expand the default stopwords list if necessary
# YOUR CODE HERE!
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package reuters to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#btc_headlines
#eth_headlines
btc_text = btc_df['text']
btc_text_only = btc_text.to_string()
eth_text = eth_df['text']
eth_text_only = eth_text.to_string()

# %%
# Complete the tokenizer function
btc_tokenized = [sent_tokenize(i) for i in btc_text_only]
eth_tokenized = [sent_tokenize(i) for i in eth_text_only]

# %%
btc_word_tokenized = []

for story in btc_tokenized:
    # get all for each article, which is already sentence tokenized
    words = []
    for sent in btc_text_only:
        words = words + word_tokenize(sent)
    # append all words for each article to the word_tokenized list
    word_tokenized.append(words)

# %%
btc_word_tokenized = []

for story in btc_tokenized:
    words = []
    for sent in story:
        words = words + word_tokenize(sent)
    btc_word_tokenized.append(words)

# %%
eth_word_tokenized = []

for story in eth_tokenized:
    words = []
    for sent in story:
        words = words + word_tokenize(sent)
    eth_word_tokenized.append(words)

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', btc_text_only)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
btc_processed = process_text(btc_text_only)
print(btc_processed)
# Out:
# ['like', 'dogecoin', 'devotee', 'mayor', 'reno', 'filed', 'underrnthe', 'supply', 'chain', 'attack', 'ha', 'image', 'copyrightgetty', 'imagesrnthe', 'gang', 'behind', 'get', 'roundup', 'techcrunchs', 'biggest', 'mo', 'retail', 'investor', 'grew', 'comfortable', 'b', 'longtime', 'techcrunch', 'reader', 'know', 'well', 'mich', 'representation', 'virtual', 'currency', 'bitcoin', 'representation', 'virtual', 'cryptocurrency', 'reuters', 'staffrnfile', 'photo', 'representation', 'james', 'martincnetrna', 'uk', 'man', 'wa', 'arrested', 'reuters', 'staffrnjune', 'reuters', 'bitcoi', 'representation', 'virtual', 'currency', 'bitcoin', 'reuters', 'staffrnjune', 'reuters', 'bitcoi', 'reuters', 'staffrnfile', 'photo', 'representati', 'representation', 'virtual', 'currency', 'bitcoin', 'representations', 'cryptocurrencies', 'bitcoin', 'e', 'opinions', 'expressed', 'entrepreneur', 'contributor', 'opinions', 'expressed', 'entrepreneur', 'contributor', 'representations', 'virtual', 'currency', 'bitcoin', 'ar', 'image', 'captionthe', 'group', 'recently', 'demanded', 'hug', 'representations', 'bitcoin', 'cryptocurrency', 'ransomware', 'attack', 'fueled', 'covid', 'pandemi', 'circle', 'ha', 'announced', 'plan', 'become', 'world', 'ha', 'known', 'month', 'representations', 'bitcoin', 'cryptocurrency', 'london', 'july', 'reuters', 'bitcoin', 'fell', 'tu', 'eric', 'gravengaard', 'ceo', 'athena', 'bitcoin', 'inc', 'posted', 'rntesla', 'likely', 'start', 'taking', 'bit', 'story', 'originally', 'appeared', 'beincrypto', 'article', 'wa', 'translated', 'spanish', 'e', 'reuters', 'staffrnjuly', 'reuters', 'square', 'representation', 'virtual', 'currency', 'bitcoin', 'bitcoin', 'virtual', 'currency', 'logo', 'pictured', 'posted', 'rntesla', 'likely', 'start', 'taking', 'bit', 'representations', 'bitcoin', 'cryptocurrency', 'representations', 'bitcoin', 'cryptocurrency', 'london', 'july', 'reuters', 'chinas', 'share', 'gl', 'ark', 'investrncathie', 'wood', 'doubled', 'yuriko', 'nakaogetty', 'imagesrnmexicos', 'central', 'fine', 'print', 'following', 'comment', 'bitcoin', 'ethereumrnyuriko', 'nakaornether', 'george', 'soros', 'one', 'world', 'famous', 'regulators', 'paying', 'close', 'attention', 'c', 'elon', 'musk', 'said', 'twothirds', 'personal', 'morgan', 'stanley', 'beat', 'fourthquarter', 'expectation', 'hong', 'kongshanghai', 'july', 'reuters', 'large', 'b', 'representation', 'ethereum', 'virtual', 'currenc', 'new', 'york', 'june', 'reuters', 'ether', 'investment', 'chinese', 'flag', 'seen', 'among', 'representation', 'bitcoinrnnurphoto', 'getty', 'imagesrna', 'swath', 'representations', 'bitcoin', 'cryptocurrency', 'reuters', 'staffrnbangkok', 'july', 'reuters', 'london', 'reuters', 'regulators', 'getting', 'anxi', 'author', 'editoratlarge', 'finance', 'representation', 'virtual', 'cryptocurrency', 'july', 'reuters', 'companies', 'transfer', 'bi', 'bitcoin', 'mining', 'computer', 'pictured', 'bitma', 'london', 'june', 'reuters', 'bitcoin', 'monday', 'file', 'photo', 'bank', 'england', 'seen', 'story', 'originally', 'appeared', 'beincrypto', 'london', 'july', 'reuters', 'highlyspeculative', 'men', 'buy', 'snack', 'store', 'bitcoins', 'shanghai', 'june', 'reuters', 'chinas', 'sweeping', 'reuters', 'staffrnnew', 'york', 'june', 'reuters', 'michael', 'saylor', 'ceo', 'microstrategyrnjoe', 'ra', 'elon', 'musk', 'said', 'wednesday', 'company', 'tes', 'bitcoin', 'ha', 'lost', 'around', 'half', 'value', 'since', 'get', 'roundup', 'techcrunchs', 'biggest', 'mo', 'david', 'mcnewafp', 'via', 'getty', 'ark', 'invest', 'patrici', 'twitter', 'ceo', 'jack', 'dorsey', 'said', 'part', 'driv', 'greenidge', 'allowed', 'take', 'million', 'ga', 'gary', 'gensler', 'working', 'bidens', 'financial', 'r', 'thecrypto', 'paymentsrn', 'market', 'gain', 'steam', 'lots', 'computing', 'power', 'used', 'bitcoin', 'min', 'opinions', 'expressed', 'entrepreneur', 'contributor', 'article', 'wa', 'translated', 'spanish', 'e', 'small', 'toy', 'figure', 'representation', 'nduka', 'orjin ...

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
eth_processed = process_text(eth_text_only)
print(eth_processed)
# Out:
# ['like', 'dogecoin', 'devotee', 'mayor', 'reno', 'filed', 'underrnthe', 'supply', 'chain', 'attack', 'ha', 'image', 'copyrightgetty', 'imagesrnthe', 'gang', 'behind', 'get', 'roundup', 'techcrunchs', 'biggest', 'mo', 'retail', 'investor', 'grew', 'comfortable', 'b', 'longtime', 'techcrunch', 'reader', 'know', 'well', 'mich', 'representation', 'virtual', 'currency', 'bitcoin', 'representation', 'virtual', 'cryptocurrency', 'reuters', 'staffrnfile', 'photo', 'representation', 'james', 'martincnetrna', 'uk', 'man', 'wa', 'arrested', 'reuters', 'staffrnjune', 'reuters', 'bitcoi', 'representation', 'virtual', 'currency', 'bitcoin', 'reuters', 'staffrnjune', 'reuters', 'bitcoi', 'reuters', 'staffrnfile', 'photo', 'representati', 'representation', 'virtual', 'currency', 'bitcoin', 'representations', 'cryptocurrencies', 'bitcoin', 'e', 'opinions', 'expressed', 'entrepreneur', 'contributor', 'opinions', 'expressed', 'entrepreneur', 'contributor', 'representations', 'virtual', 'currency', 'bitcoin', 'ar', 'image', 'captionthe', 'group', 'recently', 'demanded', 'hug', 'representations', 'bitcoin', 'cryptocurrency', 'ransomware', 'attack', 'fueled', 'covid', 'pandemi', 'circle', 'ha', 'announced', 'plan', 'become', 'world', 'ha', 'known', 'month', 'representations', 'bitcoin', 'cryptocurrency', 'london', 'july', 'reuters', 'bitcoin', 'fell', 'tu', 'eric', 'gravengaard', 'ceo', 'athena', 'bitcoin', 'inc', 'posted', 'rntesla', 'likely', 'start', 'taking', 'bit', 'story', 'originally', 'appeared', 'beincrypto', 'article', 'wa', 'translated', 'spanish', 'e', 'reuters', 'staffrnjuly', 'reuters', 'square', 'representation', 'virtual', 'currency', 'bitcoin', 'bitcoin', 'virtual', 'currency', 'logo', 'pictured', 'posted', 'rntesla', 'likely', 'start', 'taking', 'bit', 'representations', 'bitcoin', 'cryptocurrency', 'representations', 'bitcoin', 'cryptocurrency', 'london', 'july', 'reuters', 'chinas', 'share', 'gl', 'ark', 'investrncathie', 'wood', 'doubled', 'yuriko', 'nakaogetty', 'imagesrnmexicos', 'central', 'fine', 'print', 'following', 'comment', 'bitcoin', 'ethereumrnyuriko', 'nakaornether', 'george', 'soros', 'one', 'world', 'famous', 'regulators', 'paying', 'close', 'attention', 'c', 'elon', 'musk', 'said', 'twothirds', 'personal', 'morgan', 'stanley', 'beat', 'fourthquarter', 'expectation', 'hong', 'kongshanghai', 'july', 'reuters', 'large', 'b', 'representation', 'ethereum', 'virtual', 'currenc', 'new', 'york', 'june', 'reuters', 'ether', 'investment', 'chinese', 'flag', 'seen', 'among', 'representation', 'bitcoinrnnurphoto', 'getty', 'imagesrna', 'swath', 'representations', 'bitcoin', 'cryptocurrency', 'reuters', 'staffrnbangkok', 'july', 'reuters', 'london', 'reuters', 'regulators', 'getting', 'anxi', 'author', 'editoratlarge', 'finance', 'representation', 'virtual', 'cryptocurrency', 'july', 'reuters', 'companies', 'transfer', 'bi', 'bitcoin', 'mining', 'computer', 'pictured', 'bitma', 'london', 'june', 'reuters', 'bitcoin', 'monday', 'file', 'photo', 'bank', 'england', 'seen', 'story', 'originally', 'appeared', 'beincrypto', 'london', 'july', 'reuters', 'highlyspeculative', 'men', 'buy', 'snack', 'store', 'bitcoins', 'shanghai', 'june', 'reuters', 'chinas', 'sweeping', 'reuters', 'staffrnnew', 'york', 'june', 'reuters', 'michael', 'saylor', 'ceo', 'microstrategyrnjoe', 'ra', 'elon', 'musk', 'said', 'wednesday', 'company', 'tes', 'bitcoin', 'ha', 'lost', 'around', 'half', 'value', 'since', 'get', 'roundup', 'techcrunchs', 'biggest', 'mo', 'david', 'mcnewafp', 'via', 'getty', 'ark', 'invest', 'patrici', 'twitter', 'ceo', 'jack', 'dorsey', 'said', 'part', 'driv', 'greenidge', 'allowed', 'take', 'million', 'ga', 'gary', 'gensler', 'working', 'bidens', 'financial', 'r', 'thecrypto', 'paymentsrn', 'market', 'gain', 'steam', 'lots', 'computing', 'power', 'used', 'bitcoin', 'min', 'opinions', 'expressed', 'entrepreneur', 'contributor', 'article', 'wa', 'translated', 'spanish', 'e', 'small', 'toy', 'figure', 'representation', 'nduka', 'orjin ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
token_count(btc_processed)
# Out:
# [('reuters', 26),
#  ('bitcoin', 24),
#  ('representation', 11),
#  ('virtual', 9),
#  ('cryptocurrency', 9),
#  ('representations', 8),
#  ('july', 8),
#  ('currency', 6),
#  ('e', 6),
#  ('ha', 5)]

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
token_count(eth_processed)
# Out:
# [('reuters', 26),
#  ('bitcoin', 24),
#  ('representation', 11),
#  ('virtual', 9),
#  ('cryptocurrency', 9),
#  ('representations', 8),
#  ('july', 8),
#  ('currency', 6),
#  ('e', 6),
#  ('ha', 5)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
from nltk.util import ngrams
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
btc_wc = WordCloud().generate(btc_processed)
plt.imshow(btc_wc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-1167618180f3> in <module>
#       1 # Generate the Bitcoin word cloud
#       2 # YOUR CODE HERE!
# ----> 3 btc_wc = WordCloud().generate(btc_processed)
#       4 plt.imshow(btc_wc)
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     611         self
#     612         """
# --> 613         words = self.process_text(text)
#     614         self.generate_from_frequencies(words)
#     615         return self
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in process_text(self, text)
#     573         regexp = self.regexp if self.regexp is not None else pattern
#     574
# --> 575         words = re.findall(regexp, text, flags)
#     576         # remove 's
#     577         words = [word[:-2] if word.lower().endswith("'s") else word
#
# ~\anaconda3\lib\re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
eth_wc = WordCloud().generate(btc_processed)
plt.imshow(eth_wc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-491ec270f44d> in <module>
#       1 # Generate the Ethereum word cloud
#       2 # YOUR CODE HERE!
# ----> 3 eth_wc = WordCloud().generate(btc_processed)
#       4 plt.imshow(eth_wc)
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_text(self, text)
#     611         self
#     612         """
# --> 613         words = self.process_text(text)
#     614         self.generate_from_frequencies(words)
#     615         return self
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in process_text(self, text)
#     573         regexp = self.regexp if self.regexp is not None else pattern
#     574
# --> 575         words = re.findall(regexp, text, flags)
#     576         # remove 's
#     577         words = [word[:-2] if word.lower().endswith("'s") else word
#
# ~\anaconda3\lib\re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in c:\users\lucas\anaconda3\lib\site-packages (from en-core-web-sm==3.1.0) (3.1.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.7 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.7)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.20.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.59.0)
# Requirement already satisfied: setuptools in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (52.0.0.post20210125)
# Requirement already satisfied: packaging>=20.0 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (20.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.21.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.3.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: jinja2 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\lucas\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lucas\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lucas\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.10.0.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\lucas\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\lucas\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\lucas\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2021.5.30)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\lucas\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0.0rc2 in c:\users\lucas\anaconda3\lib\site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!
btc_text_only
# Out:
# '0     Like Dogecoin devotees, the mayor of Reno, and...\n1     Filed under:\\r\\nThe supply chain attack has re...\n2     image copyrightGetty Images\\r\\nThe gang behind...\n3     To get a roundup of TechCrunchs biggest and mo...\n4     While retail investors grew more comfortable b...\n5     As longtime TechCrunch readers know well, Mich...\n6     A representation of virtual currency Bitcoin i...\n7     A representation of the virtual cryptocurrency...\n8     By Reuters Staff\\r\\nFILE PHOTO: Representation...\n9     James Martin/CNET\\r\\nA UK man was arrested in ...\n10    By Reuters Staff\\r\\nJune 25 (Reuters) - Bitcoi...\n11    A representations of virtual currency Bitcoin ...\n12    By Reuters Staff\\r\\nJune 25 (Reuters) - Bitcoi...\n13    By Reuters Staff\\r\\nFILE PHOTO: A representati...\n14    A representation of virtual currency bitcoin i...\n15    Representations of cryptocurrencies Bitcoin, E...\n16    Opinions expressed by Entrepreneur contributor...\n17    Opinions expressed by Entrepreneur contributor...\n18    Representations of virtual currency bitcoin ar...\n19    image captionThe group recently demanded a hug...\n20    Representations of the Bitcoin cryptocurrency ...\n21    Ransomware attacks, fueled by COVID-19 pandemi...\n22    Circle has announced that it plans to become a...\n23    The world has known for months that more than ...\n24    Representations of the Bitcoin cryptocurrency ...\n25    LONDON, July 20 (Reuters) - Bitcoin fell on Tu...\n26    Eric Gravengaard, CEO of Athena Bitcoin Inc. s...\n27    Posted \\r\\nTesla is likely to start taking bit...\n28    This story originally appeared on be[IN]crypto...\n29    This article was translated from our Spanish e...\n30    By Reuters Staff\\r\\nJuly 9 (Reuters) - Square ...\n31    A representation of virtual currency Bitcoin i...\n32    A Bitcoin (virtual currency) logo is pictured ...\n33    Posted \\r\\nTesla is likely to start taking bit...\n34    Representations of the Bitcoin cryptocurrency ...\n35    Representations of the Bitcoin cryptocurrency ...\n36    LONDON, July 15 (Reuters) - Chinas share of gl...\n37    ARK Invest\\r\\nCathie Wood doubled down on her ...\n38    Yuriko Nakao/Getty Images\\r\\nMexico\'s central ...\n39    The Fine Print: The following comments are own...\n40    Bitcoin and Ethereum\\r\\nYuriko Nakao\\r\\nEther ...\n41    George Soros is one of the world\'s most famous...\n42    Regulators are paying close attention to the c...\n43    Elon Musk said two-thirds of the "personal and...\n44    Morgan Stanley beat fourth-quarter expectation...\n45    HONG KONG/SHANGHAI, July 7 (Reuters) - Large b...\n46    Representation of the Ethereum virtual currenc...\n47    NEW YORK, June 28 (Reuters) - Ether investment...\n48    A Chinese flag is seen among representations o...\n49    Bitcoin\\r\\nNurphoto / Getty Images\\r\\nA swath ...\n50    Representations of the Bitcoin cryptocurrency ...\n51    By Reuters Staff\\r\\nBANGKOK, July 8 (Reuters) ...\n52    LONDON (Reuters) - Regulators are getting anxi...\n53    (The author is editor-at-large for finance and...\n54    A representation of the virtual cryptocurrency...\n55    July 20 (Reuters) - Companies that transfer bi...\n56    Bitcoin mining computers are pictured in Bitma...\n57    LONDON, June 28 (Reuters) - Bitcoin on Monday ...\n58    FILE PHOTO: The Bank of England can be seen as...\n59    This story originally appeared on be[IN]crypto...\n60    LONDON, July 13 (Reuters) - Highly-speculative...\n61    Men buy snacks at a store where bitcoins are a...\n62    SHANGHAI, June 25 (Reuters) - China\'s sweeping...\n63    By Reuters Staff\\r\\nNEW YORK, June 24 (Reuters...\n64    Michael Saylor, CEO of MicroStrategy\\r\\nJoe Ra...\n65    Elon Musk said Wednesday that his company, Tes...\n66    Bitcoin has lost around half its value since A...\n67    To get a roundup of TechCrunchs biggest and mo...\n68    David McNew/AFP via Getty; ARK Invest; Patrici...\n69    Twitter CEO Jack Do ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
btc_doc = nlp(btc_text_only)
# Add a title to the document
# YOUR CODE HERE!
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">0     Like Dogecoin devotees, the mayor of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reno
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Filed under:\r\nThe supply chain attack has re...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      image copyrightGetty Images\r\nThe gang behind...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      To get a roundup of TechCrunchs biggest and mo...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      While retail investors grew more comfortable b...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      As longtime TechCrunch readers know well,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      A representation of virtual currency Bitcoin i...</br>7     A representation of the virtual cryptocurrency...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      By
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Staff\r\nFILE PHOTO: Representation...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Martin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /CNET\r\nA
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  man was arrested in ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     By
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Staff\r\nJune
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoi...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     A representations of virtual currency Bitcoin ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     By
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Staff\r\nJune
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoi...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     By
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem"

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!
eth_text_only
# Out:
# '0     There are many blockchain platforms competing ...\n1     While retail investors grew more comfortable b...\n2     Bitcoin and Ethereum\\r\\nYuriko Nakao\\r\\nEther ...\n3     "Anthony Di Iorio, a co-founder of the Ethereu...\n4     Ether holders have "staked" more than $13 bill...\n5     Ether is the cryptocurrency of the ethereum ne...\n6     Major upgrades to the ethereum network could h...\n7     You’ve likely seen the headlines surrounding t...\n8     While the ambitions of crypto investors have s...\n9     Personal Finance Insider writes about products...\n10    This article was translated from our Spanish e...\n11    By Reuters Staff\\r\\nJune 25 (Reuters) - Bitcoi...\n12    By Reuters Staff\\r\\nJune 25 (Reuters) - Bitcoi...\n13    After a successful testnet deployement, the Lo...\n14    By Reuters Staff\\r\\nFILE PHOTO: Representation...\n15    At this point the average Hackaday reader is l...\n16    A representations of virtual currency Bitcoin ...\n17    A representation of the virtual cryptocurrency...\n18    All the sessions from Transform 2021 are avail...\n19    Representations of cryptocurrencies Bitcoin, E...\n20    Representations of virtual currency bitcoin ar...\n21    Representations of cryptocurrencies Bitcoin, E...\n22    Representation of the Ethereum virtual currenc...\n23    NEW YORK (Reuters) - Cryptocurrency investment...\n24    Non-fungible token platform Mintable raised $1...\n25    Chung Sung-Jun/Getty Images\\r\\nOpenSea, a mark...\n26    Rafael Henrique/SOPA Images/LightRocket via Ge...\n27    Indicted Ethereum Foundation developer Virgil ...\n28    College Hunks’\xa0first franchisee didn’t have en...\n29    These pixelated avatars, known as "CryptoPunks...\n30    This article was translated from our Spanish e...\n31    The world of Non-Fungible Tokens (NFTs) offers...\n32    By Reuters Staff\\r\\nFILE PHOTO: Representation...\n33    ETHEREUM: THE INFINITE GARDEN is a “feature-le...\n34    If you are an investor who dabbles in cryptocu...\n35    Representations of cryptocurrencies Bitcoin, E...\n36    World Wide Web founder Tim Berners-Lee poses f...\n37    A representation of the virtual cryptocurrency...\n38    FILE PHOTO: Representations of cryptocurrencie...\n39    Ransomware attacks, fueled by COVID-19 pandemi...\n40    This article was translated from our Spanish e...\n41    This article was translated from our Spanish e...\n42    June\\r\\n24, 2021\\r\\n11 min read\\r\\nThis story ...\n43    LONDON Bids for a non-fungible token of the or...\n44    Traders and financial professionals work on th...\n45    Dogecoin spinoff shiba inu spiked to its highe...\n46    The internet nowadays is ephemeral. Layers upo...\n47    Costfoto/Barcroft Media via Getty Images\\r\\nDe...\n48    Elon Musk said two-thirds of the "personal and...\n49    Representations of virtual currency bitcoin on...\n50    Representations of the Bitcoin cryptocurrency ...\n51    Representations of cryptocurrencies Bitcoin, E...\n52    A representation of the virtual cryptocurrency...\n53    Representations of cryptocurrencies Bitcoin, E...\n54    NEW YORK, June 28 (Reuters) - Ether investment...\n55    LONDON, June 24 (Reuters) - Andy Murray is cas...\n56    A representation of the virtual cryptocurrency...\n57    Where does your enterprise stand on the AI ado...\n58    Opinions expressed by Entrepreneur contributor...\n59    Personal Finance Insider writes about products...\n60    Opinions expressed by Entrepreneur contributor...\n61    Xinhua/Wang Ying/ Getty Images\\r\\n<ul><li>US s...\n62    This article was translated from our Spanish e...\n63    All the sessions from Transform 2021 are avail...\n64    Speaking remotely at the B Word Conference\xa0tod...\n65    Enlarge/ Berners-Lee reflecting on the creatio...\n66    Stocks are set to continue inching higher on T...\n67    LONDON, June 24 (Reuters) - Andy Murray is cas...\n68    A representation of virtual currency Bitcoin i...\n69    LONDON (Reuters) - The market  ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
eth_doc = nlp(eth_text_only)
# Add a title to the document
# YOUR CODE HERE!
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">0     There are many blockchain platforms competing ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      While retail investors grew more comfortable b...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      &quot;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anthony Di Iorio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a co-founder of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Ether holders have &quot;staked&quot;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  bill...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Ether is the cryptocurrency of the ethereum ne...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Major upgrades to the ethereum network could h...</br>7     You’ve likely seen the headlines surrounding t...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      While the ambitions of crypto investors have s...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Personal Finance Insider writes about products...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     This article was translated from our
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  e...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     By
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Staff\r\nJune
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoi...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     By
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Staff\r\nJune
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoi...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     After a successful testnet deployement, the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; bor

# %% [markdown]
# ---
